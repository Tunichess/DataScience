# %% [markdown]
# # Artificial Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install -U -q PyDrive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Importing the dataset
fichier_path=r'/content/drive/My Drive/data/Churn_Modelling.csv'
dataset=pd.read_csv(fichier_path)
dataset
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...               0       113931.57      1
# 3             4    15701354       Boni  ...               0        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# ...

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# Encoding categorical data
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
ct = ColumnTransformer([("Country", OneHotEncoder(), [1])],remainder = 'passthrough')
X = ct.fit_transform(X).toarray()
X = X[:, 1:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-40938e02ce20> in <module>()
#       5 X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
#       6 ct = ColumnTransformer([("Country", OneHotEncoder(), [1])],remainder = 'passthrough')
# ----> 7 X = ct.fit_transform(X).toarray()
#       8 X = X[:, 1:]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 100, kernel_initializer = 'uniform', activation = 'relu',input_dim = 10))
# Adding the second hidden layer
classifier.add(Dense(units = 100, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 100, kernel_initializer = 'uniform', activation = 'relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 50)
# Out:
# Epoch 1/50
# 8000/8000 [==============================] - 2s 198us/step - loss: 0.4266 - accuracy: 0.8198
# Epoch 2/50
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.3636 - accuracy: 0.8506
# Epoch 3/50
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.3555 - accuracy: 0.8560
# Epoch 4/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3508 - accuracy: 0.8559
# Epoch 5/50
# 8000/8000 [==============================] - 1s 161us/step - loss: 0.3442 - accuracy: 0.8621
# Epoch 6/50
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.3427 - accuracy: 0.8610
# Epoch 7/50
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.3398 - accuracy: 0.8620
# Epoch 8/50
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.3373 - accuracy: 0.8625
# Epoch 9/50
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3348 - accuracy: 0.8624
# Epoch 10/50
# ...

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1467,  128],
#        [ 204,  201]])

# %%
# Predicting a single new observation
"""Predict if the customer with the following informations will leave the bank:
Geography: France
Credit Score: 600
Gender: Male
Age: 40
Tenure: 3
Balance: 60000
Number of Products: 2
Has Credit Card: Yes
Is Active Member: Yes
Estimated Salary: 50000"""
new_prediction = classifier.predict(sc.transform(np.array([[0.0, 0, 600, 1, 40, 3, 60000, 2, 1, 50000]])))
new_prediction = (new_prediction > 0.5)
new_prediction
# Out:
# array([[ True]])
